# %% [markdown]
# ### Notebook Summary

# %% [markdown]
# * Loads training and test audio clips of cats and dogs
# * Randomly selects and plays clips

# %% [markdown]
# ### Imports and Paths

# %%
import sys
from os import path
import glob
from os import listdir

import numpy as np
import random

# %% [markdown]
# **For playing audio clips in `wav` format**

# %%
from IPython.display import Audio
import scipy.io.wavfile as wave

# %%
BASE_DIR = "/Users/susmitadatta/Projects/AudioClassification_CatDog/"
SUPMOD_DIR = BASE_DIR+"SupportModules/"
sys.path.append(path.abspath(SUPMOD_DIR))
import par_dirpath as PAR

# %% [markdown]
# **Directory paths are defined in the parameter file.**

# %%
DATA_DIR = PAR.DATA_DIR
CODE_DIR = PAR.CODE_DIR
SUPMOD_DIR = PAR.SUPMOD_DIR

TRAIN_CAT_DIR = PAR.TRAIN_CAT_DIR
TRAIN_DOG_DIR = PAR.TRAIN_DOG_DIR
TEST_CAT_DIR = PAR.TEST_CAT_DIR
TEST_DOG_DIR = PAR.TEST_DOG_DIR

# %% [markdown]
# ### Load Data

# %% [markdown]
# **Cat training data**

# %%
train_cat_files = listdir(TRAIN_CAT_DIR)
print("There are", len(train_cat_files), "training audio clips.")
# Out:
# There are 125 training audio clips.

# %% [markdown]
# **Dog training data**

# %%
train_dog_files = listdir(TRAIN_DOG_DIR)
print("There are", len(train_dog_files), "training audio clips.")
# Out:
# There are 85 training audio clips.

# %% [markdown]
# **Cat test data**

# %%
test_cat_files = listdir(TEST_CAT_DIR)
print("There are", len(test_cat_files), "test audio clips.")
# Out:
# There are 39 test audio clips.

# %% [markdown]
# **Dog test data**

# %%
test_dog_files = listdir(TEST_DOG_DIR)
print("There are", len(test_dog_files), "test audio clips.")
# Out:
# There are 28 test audio clips.

# %% [markdown]
# ### Play Clips

# %%
cat_clip = random.choice(train_cat_files)
print("Playing clip", cat_clip)
Audio(TRAIN_CAT_DIR+cat_clip)
# Out:
# Playing clip cat_6.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dog_clip = random.choice(train_dog_files)
print("Playing clip", dog_clip)
Audio(TRAIN_DOG_DIR+dog_clip)
# Out:
# Playing clip dog_barking_84.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
